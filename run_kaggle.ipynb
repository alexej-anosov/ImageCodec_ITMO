# %%
# !git clone https://github.com/alexej-anosov/ImageCodec_ITMO
# Out:
# Cloning into 'ImageCodec_ITMO'...
# remote: Enumerating objects: 710, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 710 (delta 36), reused 48 (delta 27), pack-reused 649 (from 1)
# Receiving objects: 100% (710/710), 32.70 MiB | 44.41 MiB/s, done.
# Resolving deltas: 100% (260/260), done.

# %%
# %pwd
# Out:
# '/kaggle/working'

# %%
# %cd ./ImageCodec_ITMO
# Out:
# /kaggle/working/ImageCodec_ITMO

# %%
# %pwd
# Out:
# '/kaggle/working/ImageCodec_ITMO'

# %%
# !chmod +x run.sh

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !wandb login

# %%
# !python EntropySetup.py build_ext --inplace
# Out:
# In file included from wrapper.cpp:5:
# ImageCoder.cpp: In function 'int BitPlaneEncoder(unsigned char*, unsigned char*, int, int, int, int*)':
# ImageCoder.cpp:21:38: warning: ISO C++ forbids converting a string constant to 'char*' [-Wwrite-strings]
#    21 |         biari_init_context(&bin_ctx, "ctx");
#       |                                      ^~~~~
# ImageCoder.cpp: In function 'int BitPlaneDecoder(unsigned char*, unsigned char*, int, int, int, int*)':
# ImageCoder.cpp:56:38: warning: ISO C++ forbids converting a string constant to 'char*' [-Wwrite-strings]
#    56 |         biari_init_context(&bin_ctx, "ctx");
#       |                                      ^~~~~
# In file included from wrapper.cpp:6:
# ac_enc.cpp: In function 'void biari_encode_symbol(EncodingEnvironmentPtr, int, BiContextTypePtr)':
# ac_enc.cpp:107:25: warning: ISO C++17 does not allow 'register' storage class specifier [-Wregister]
#   107 |   register unsigned int range = eep->Erange;
# ...

# %%
# !pip install .
# Out:
# Processing /kaggle/working/ImageCodec_ITMO
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for src: filename=src-0.1.0-py3-none-any.whl size=950 sha256=7e2bd8ad011cfe2f8e58dd1a19780690eb6fdcb47ac3cd9048fa1cd3c5ea7ac8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e0b5_duf/wheels/bd/59/ce/e6371d8b133199bc565124f3797ceaa68b6a6a26e7e05ecdde
# Successfully built src
# ...
#   Attempting uninstall: src
#     Found existing installation: src 0.1.0
#     Uninstalling src-0.1.0:
#       Successfully uninstalled src-0.1.0
# ...

# %%
# !python -m src.scripts.train --config_file configs/train/base_ae_b32_s6000_lr3e3_orthogonal_bottleneck_gelu.yml
# Out:
# wandb: Currently logged in as: alexej-anosov. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.18.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.6
# wandb: Run data is saved locally in /kaggle/working/ImageCodec_ITMO/wandb/run-20241001_005633-tpwnvqxq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run base_ae_b32_s6000_lr3e4_orthogonal_bottleneck_gelu
# wandb: ⭐️ View project at https://wandb.ai/alexej-anosov/codec_ITMO
# wandb: 🚀 View run at https://wandb.ai/alexej-anosov/codec_ITMO/runs/tpwnvqxq
# {'init_method': 'orthogonal', 'activation': 'gelu'}
# 2024-10-01 00:56:50.034 | INFO     | __main__:main:66 - ***** Running training *****
# 2024-10-01 00:56:50.035 | INFO     | __main__:main:67 - Num examples = 204
# 2024-10-01 00:56:50.035 | INFO     | __main__:main:68 - Num Epochs = 6000
# ...
